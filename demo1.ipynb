# %% [markdown]
# <h1>Fundamentals of AI</h1>
# <h2>Demo #1 - Intro to Jupyter Labs</h2>

# %% [markdown]
# <b>This is a Markdown cell you can use to create structured text</b>

# %% [raw]
# This is a raw text cell you can use for simple text

# %%
# This is a python code cell you can use to create and run machine learning models

str1 = 'hello, world'

print(str1)

str2 = 'hello ' + 'machine ' + 'learning'

print(str2)
# Out:
# hello, world
# hello machine learning

# %%
# This is a python code cell you can use to generate plots of data and results

import matplotlib.pyplot as plt

plt.plot([.9, .5, .2, .1, .05, .05, .045, .045, .045, .045, .045, .045, .045, .045, .045, .045])
plt.plot([.98, .76, .35, .2, .1, 0.07, 0.05, .05, .07, .09, .15, .18, .20, .225, .25, .275])
plt.ylabel('loss')
plt.xlabel('epochs')
plt.show()

# %%
# This is a python code cell you can use to generate plots of data and results

import matplotlib.pyplot as plt

plt.plot([.9, .5, .3, .2, .3, .25, .25, .21, .29, .25, .21, .23, .22, .21, .22, .21])
plt.plot([.98, .76, .35, .34, .33, 0.33, 0.33, .34, .34, .35, .34, .35, .34, .35, .34, .35])
plt.ylabel('loss')
plt.xlabel('epochs')
plt.savefig("underfitting2.jpg")
plt.show()
